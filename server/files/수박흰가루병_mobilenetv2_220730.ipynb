# %%
# !pip install 'tensorflow == 2.3.0'
# Out:
# ERROR: Invalid requirement: "'tensorflow"

# %%
import os
import numpy as np
import shutil
import time

# %%
# %pwd
# Out:
# 'C:\\Users\\LG\\anaconda3\\envs\\roadmap'

# %%
rootdir= './수박/' #path of the original folder
classes = ['수박정상', '수박흰가루병']

# %%
# !rm -rf './train'  # 리눅스명령어? rm -파일 혹은 디렉토리 삭제
# !rm -rf './valid'
# Out:
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
for i in classes:
    os.makedirs('./수박/train/' + i)
    os.makedirs('./수박/valid/' + i)
    source = rootdir + '/' + i
    allFileNames = os.listdir(source)
    print(allFileNames)
    np.random.shuffle(allFileNames)
    test_ratio = 0.25
    train_FileNames, test_FileNames = np.split(np.array(allFileNames),[int(len(allFileNames)*(1 - test_ratio))])
    train_FileNames = [source+'/'+ name for name in train_FileNames.tolist()]
    test_FileNames = [source+'/'+ name for name in test_FileNames.tolist()]
    for name in train_FileNames:
        shutil.copy(name,'./수박/train/' + i)
    for name in test_FileNames:
        shutil.copy(name,'./수박/valid/' + i)
# Out:
# ['수박정상_1.jpg', '수박정상_10.jpg', '수박정상_100.jpg', '수박정상_1000.jpg', '수박정상_101.jpg', '수박정상_102.jpg', '수박정상_103.jpg', '수박정상_104.jpg', '수박정상_105.jpg', '수박정상_106.jpg', '수박정상_107.jpg', '수박정상_108.jpg', '수박정상_109.jpg', '수박정상_11.jpg', '수박정상_110.jpg', '수박정상_111.jpg', '수박정상_112.jpg', '수박정상_113.jpg', '수박정상_114.jpg', '수박정상_115.jpg', '수박정상_116.jpg', '수박정상_117.jpg', '수박정상_118.jpg', '수박정상_119.jpg', '수박정상_12.jpg', '수박정상_120.jpg', '수박정상_121.jpg', '수박정상_122.jpg', '수박정상_123.jpg', '수박정상_124.jpg', '수박정상_125.jpg', '수박정상_126.jpg', '수박정상_127.jpg', '수박정상_128.jpg', '수박정상_129.jpg', '수박정상_13.jpg', '수박정상_130.jpg', '수박정상_131.jpg', '수박정상_132.jpg', '수박정상_133.jpg', '수박정상_134.jpg', '수박정상_135.jpg', '수박정상_136.jpg', '수박정상_137.jpg', '수박정상_138.jpg', '수박정상_139.jpg', '수박정상_14.jpg', '수박정상_140.jpg', '수박정상_141.jpg', '수박정상_142.jpg', '수박정상_143.jpg', '수박정상_144.jpg', '수박정상_145.jpg', '수박정상_146.jpg', '수박정상_147.jpg', '수박정상_148.jpg', '수박정상_149.jpg', '수박정상_15.jpg', '수박정상_150.jpg', '수박정상_151.jpg', '수박정상_152.jpg', '수박정상_153.jpg', '수박정상_154.jpg', '수박정상_155.jpg', '수박정상_156.jpg', '수박정상_157.jpg', '수박정상_158.jpg', '수박정상_159.jpg', '수박정상_16.jpg', '수박정상_160.jpg', '수박정상_161.jpg', '수박정상_162.jpg', '수박정상_163.jpg', '수박정상_164.jpg', '수박정상_165.jpg', '수박정상_166.jp
print(train_unhealthy_names[:10])

validation_healthy_names = os.listdir(valid_healthy_dir)
print(validation_healthy_names[:10])

validation_unhealthy_names = os.listdir(valid_unhealthy_dir)
print(validation_unhealthy_names[:10])
# Out:
# ['수박정상_100.jpg', '수박정상_101.jpg', '수박정상_103.jpg', '수박정상_104.jpg', '수박정상_106.jpg', '수박정상_109.jpg', '수박정상_11.jpg', '수박정상_110.jpg', '수박정상_112.jpg', '수박정상_113.jpg']
# ['수박흰가루병_1000.jpg', '수박흰가루병_1001.jpg', '수박흰가루병_1002.jpg', '수박흰가루병_1004.jpg', '수박흰가루병_1005.jpg', '수박흰가루병_1007.jpg', '수박흰가루병_1008.jpg', '수박흰가루병_1009.jpg', '수박흰가루병_1010.jpg', '수박흰가루병_1011.jpg']
# ['수박정상_1.jpg', '수박정상_10.jpg', '수박정상_1000.jpg', '수박정상_102.jpg', '수박정상_105.jpg', '수박정상_107.jpg', '수박정상_108.jpg', '수박정상_111.jpg', '수박정상_125.jpg', '수박정상_128.jpg']
# ['수박흰가루병_1003.jpg', '수박흰가루병_1006.jpg', '수박흰가루병_1017.jpg', '수박흰가루병_1018.jpg', '수박흰가루병_1020.jpg', '수박흰가루병_1024.jpg', '수박흰가루병_1028.jpg', '수박흰가루병_1033.jpg', '수박흰가루병_1035.jpg', '수박흰가루병_1036.jpg']

# %%
print('total training 수박정상 images:', len(os.listdir(train_healthy_dir)))
print('total training 수박흰가루병 images:', len(os.listdir(train_unhealthy_dir)))
print('total validation 수박정상 images:', len(os.listdir(valid_healthy_dir)))
print('total validation 수박흰가루병 images:', len(os.listdir(valid_unhealthy_dir)))
# Out:
# total training 수박정상 images: 978
# total training 수박흰가루병 images: 987
# total validation 수박정상 images: 326
# total validation 수박흰가루병 images: 330

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_healthy_pic = [os.path.join(train_healthy_dir, fname) 
                for fname in train_healthy_names[pic_index-8:pic_index]]
next_unhealthy_pic = [os.path.join(train_unhealthy_dir, fname) 
                for fname in train_unhealthy_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_healthy_pic + next_unhealthy_pic):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 120 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
        './수박/train/',  # This is the source directory for training images
        classes = ['수박정상', '수박흰가루병'],
        target_size=(200, 200),  # All images will be resized to 200x200
        batch_size=120,
        # Use binary labels
        class_mode='binary')

# Flow validation images in batches of 19 using valid_datagen generator
validation_generator = validation_datagen.flow_from_directory(
        './수박/valid/',  # This is the source directory for training images
        classes = ['수박정상', '수박흰가루병'],
        target_size=(200, 200),  # All images will be resized to 200x200
        batch_size=19,
        # Use binary labels
        class_mode='binary',
        shuffle=False)
# Out:
# Found 1965 images belonging to 2 classes.
# Found 656 images belonging to 2 classes.

# %%
#MobileNetV2
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
import numpy as np
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score

# %%
model = Sequential()
model.add(MobileNetV2(include_top = False, weights="imagenet", input_shape=(200, 200, 3)))
model.add(tf.keras.layers.GlobalAveragePooling2D())
model.add(Dense(1, activation = 'sigmoid'))
model.layers[0].trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 1281
#
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# model.compile(loss='binary_crossentropy',
#               optimizer=RMSprop(lr=0.001),
#               metrics=['accuracy', tf.keras.metrics.AUC()])

from tensorflow.keras import optimizers


model.compile(optimizer=RMSprop(learning_rate=0.01), loss = 'binary_crossentropy', metrics = 'accuracy')

# %%
st=time.perf_counter()
history = model.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=7,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8)
nd=time.perf_counter()
# Out:
# Epoch 1/7
# 8/8 [==============================] - 17s 2s/step - loss: 0.6137 - accuracy: 0.8384 - val_loss: 0.0845 - val_accuracy: 0.9803
# Epoch 2/7
# 8/8 [==============================] - 16s 2s/step - loss: 0.0444 - accuracy: 0.9864 - val_loss: 0.0267 - val_accuracy: 0.9868
# Epoch 3/7
# 8/8 [==============================] - 17s 2s/step - loss: 0.0233 - accuracy: 0.9979 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 4/7
# 8/8 [==============================] - 17s 2s/step - loss: 0.0226 - accuracy: 0.9969 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 5/7
# 8/8 [==============================] - 19s 2s/step - loss: 0.0152 - accuracy: 0.9990 - val_loss: 0.0309 - val_accuracy: 0.9868
# Epoch 6/7
# 8/8 [==============================] - 18s 2s/step - loss: 0.0403 - accuracy: 0.9842 - val_loss: 0.5433 - val_accuracy: 0.7829
# Epoch 7/7
# 8/8 [==============================] - 19s 2s/step - loss: 0.0376 - accuracy: 0.9833 - val_loss: 0.0170 - val_accuracy: 0.9868

# %%
print("train_time: ",nd-st)
# Out:
# train_time:  122.70419030000085

# %%
model.evaluate(validation_generator)
# Out:
# 35/35 [==============================] - 11s 320ms/step - loss: 0.0062 - accuracy: 0.9970
# [0.006200466770678759, 0.9969512224197388]

# %%
STEP_SIZE_TEST=validation_generator.n//validation_generator.batch_size
validation_generator.reset()
preds = model.predict(validation_generator,
                      verbose=1)
# Out:
# 35/35 [==============================] - 10s 277ms/step

# %%
fpr, tpr, _ = roc_curve(validation_generator.classes, preds)

# %%
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
model.save('수박흰가루병mnet2.h5')
# %matplotlib inline
# import matplotlib.pyplot as plt
# import numpy as np
# from google.colab import files
# from keras.preprocessing import image

# uploaded = files.upload()

# for fn in uploaded.keys():
 
#   # predicting images
#   path = '/content/' + fn
#   img = image.load_img(path, target_size=(200, 200))
#   x = image.img_to_array(img)
#   plt.imshow(x/255.)
#   x = np.expand_dims(x, axis=0)
#   images = np.vstack([x])
#   classes = model.predict(images, batch_size=10)
#   print(classes[0])
#   if classes[0]<0.5:
#     print(fn + " is 참외정상")
#   else:
#     print(fn + " is 참외흰가루병")

# %%
#SqueezeNet
bnmomemtum=0.9
def fire(x, squeeze, expand):
    y  = tf.keras.layers.Conv2D(filters=squeeze, kernel_size=1, activation='relu', padding='same')(x)
    y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
    y1 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=1, activation='relu', padding='same')(y)
    y1 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y1)
    y3 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=3, activation='relu', padding='same')(y)
    y3 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y3)
    return tf.keras.layers.concatenate([y1, y3])

def fire_module(squeeze, expand):
    return lambda x: fire(x, squeeze, expand)
x = tf.keras.layers.Input(shape=[200,200, 3]) # input is 200x200 pixels RGB
y = tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', use_bias=True, activation='relu')(x)
y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
y = fire_module(24, 48)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(48, 96)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(64, 128)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(48, 96)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(24, 48)(y)
y = tf.keras.layers.GlobalAveragePooling2D()(y)
y = tf.keras.layers.Dense(1, activation='sigmoid')(y)

model2 = tf.keras.Model(x, y)

model2.compile(
optimizer='adam',
loss= 'binary_crossentropy',
metrics=['accuracy'])
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 200, 200, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 200, 200, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 200, 200, 24  792         ['batch_normalization[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 200, 200, 24  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_2 (Conv2D)              (None, 200, 200, 24  600         ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 200, 200, 24  5208        ['batch_normalization_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 200, 200, 24  96         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_3 (BatchNo  (None, 200, 200, 24  96         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  concatenate (Concatenate)      (None, 200, 200, 48  0           ['batch_normalization_2[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 100, 100, 48  0           ['concatenate[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 100, 100, 48  2352        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 100, 100, 48  192        ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  conv2d_5 (Conv2D)              (None, 100, 100, 48  2352        ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 100, 100, 48  20784       ['batch_normalization_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 100, 100, 48  192        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  batch_normalization_6 (BatchNo  (None, 100, 100, 48  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  concatenate_1 (Concatenate)    (None, 100, 100, 96  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_6[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 96)  0           ['concatenate_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 50, 50, 64)   6208        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 50, 50, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 50, 50, 64)   4160        ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 50, 50, 64)   36928       ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 50, 50, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 50, 50, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 50, 50, 128)  0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 128)  0          ['concatenate_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 48)   6192        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 48)  192         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 48)   2352        ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 48)   20784       ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 48)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 48)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 25, 25, 96)   0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 96)  0           ['concatenate_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 24)   2328        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 12, 24)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 24)   600         ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 24)   5208        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 12, 24)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 12, 12, 24)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 48)   0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 48)          0           ['concatenate_4[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 1)            49          ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 120,417
# Trainable params: 119,105
# Non-trainable params: 1,312
# __________________________________________________________________________________________________

# %%
st=time.perf_counter()
history = model2.fit(
      train_generator,
      steps_per_epoch=8,  
      epochs=7,
      verbose=1,
      validation_data = validation_generator,
      validation_steps=8)
nd=time.perf_counter()
# Out:
# Epoch 1/7
# 8/8 [==============================] - 107s 13s/step - loss: 0.3838 - accuracy: 0.8497 - val_loss: 0.5349 - val_accuracy: 1.0000
# Epoch 2/7
# 8/8 [==============================] - 131s 16s/step - loss: 0.1639 - accuracy: 0.9531 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 3/7
# 8/8 [==============================] - 141s 18s/step - loss: 0.0958 - accuracy: 0.9802 - val_loss: 8.3747e-04 - val_accuracy: 1.0000
# Epoch 4/7
# 8/8 [==============================] - 116s 14s/step - loss: 0.0656 - accuracy: 0.9842 - val_loss: 5.6542e-04 - val_accuracy: 1.0000
# Epoch 5/7
# 8/8 [==============================] - 125s 16s/step - loss: 0.0475 - accuracy: 0.9875 - val_loss: 0.0461 - val_accuracy: 1.0000
# Epoch 6/7
# 8/8 [==============================] - 115s 14s/step - loss: 0.0488 - accuracy: 0.9864 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 7/7
# 8/8 [==============================] - 115s 14s/step - loss: 0.0632 - accuracy: 0.9774 - val_loss: 0.0415 - val_accuracy: 0.9803

# %%
print("train time-squeezenet: ", nd-st)
# Out:
# train time-squeezenet:  850.2286879000003

# %%
model2.evaluate(validation_generator)
# Out:
# 35/35 [==============================] - 17s 482ms/step - loss: 0.1241 - accuracy: 0.9390
# [0.12412546575069427, 0.9390243887901306]

# %%
STEP_SIZE_TEST=validation_generator.n//validation_generator.batch_size
validation_generator.reset()
preds = model2.predict(validation_generator,
                      verbose=1)
# Out:
# 35/35 [==============================] - 17s 489ms/step

# %%
fpr2, tpr2, _ = roc_curve(validation_generator.classes, preds)

# %%
roc_auc2 = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(fpr2, tpr2, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
model.save('수박흰가루병snet2.h5')

# %% [markdown]
# [참고자료] https://velog.io/@sset2323/03-05.-ROC-%EA%B3%A1%EC%84%A0%EA%B3%BC-AUC
